# %%
# Set working directory to your package root (where DESCRIPTION file is located) only if not already 'dieseoR'
if (basename(getwd()) != "dieseoR") {
  setwd("dieseoR")  # <-- Change this to your actual package path if needed
}

library(devtools)
load_all()
# Out:
# ℹ Loading dieseoR

# %%
list.files("~/workspace")
# Out:
# [1] "data"           "dieseoR"        "local.R"        "notebook.ipynb"

# %%
# 1. Deine Zugangsdaten eintragen
subdomain <- "pummys"        # Nur die Subdomain (ohne .zendesk.com)
email <- "kontakt@dieseo.de"       # Die E-Mail, mit der du dich bei Zendesk einloggst
api_token <- "IoYnQZnfSQddwuC2GnM0sqpNZmfrATUDAGDnifbV"

# %%
get_zendesk_tickets(subdomain = subdomain, email = email, api_token = api_token)
# Out:
# Lade Cursor-Seite 1 ...
#
# Lade Cursor-Seite 2 ...
#
# Lade Cursor-Seite 3 ...
#
# Lade Cursor-Seite 4 ...
#
# Lade Cursor-Seite 5 ...
#
# Lade Cursor-Seite 6 ...
#
# Lade Cursor-Seite 7 ...
#
# Lade Cursor-Seite 8 ...
#
# Lade Cursor-Seite 9 ...
#
# Lade Cursor-Seite 10 ...
#
# Lade Cursor-Seite 11 ...
#
# Lade Cursor-Seite 12 ...
#
# Lade Cursor-Seite 13 ...
#
# Lade Cursor-Seite 14 ...
#
# Lade Cursor-Seite 15 ...
#
# Lade Cursor-Seite 16 ...
#
# Lade Cursor-Seite 17 ...
#
# Lade Cursor-Seite 18 ...
#
# Lade Cursor-Seite 19 ...
#
# Lade Cursor-Seite 20 ...
#
# Lade Cursor-Seite 21 ...
#
# Lade Cursor-Seite 22 ...
#
# Lade Cursor-Seite 23 ...
#
# Lade Cursor-Seite 24 ...
#
# Lade Cursor-Seite 25 ...
#
# Lade Cursor-Seite 26 ...
#
# Lade Cursor-Seite 27 ...
#
# Lade Cursor-Seite 28 ...
#
# Lade Cursor-Seite 29 ...
#
# Lade Cursor-Seite 30 ...
#
# Lade Cursor-Seite 31 ...
#
# Lade Cursor-Seite 32 ...
#
# Lade Cursor-Seite 33 ...
#
# Lade Cursor-Seite 34 ...
#
# ...
